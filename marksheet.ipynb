# %%
# game

# %%
import random


empty=" "
wel="                                        \33[1m WELCOME  IN ROCK//PAPER//SCISSOR  GAME"
print(empty)
sel ="                     select your choice  :  ROCK    /    PAPER     /SCISSOR   "
print(wel)
print(sel)
name=input("enter player name  :")
print(empty)

draw = 0
you_win = 0
computer_win = 0
while True:

    y = input("select your choice     :").lower()
    print(empty)
    c = random.choice(["rock", "paper", "scissor"])

    print(name, "   :", y)
    print("computer   :", c)

    if y == c:
        print("       ############   draw  ############")
        draw=draw + 1
    elif y == "rock" and c == "scissor":
        print("       ############   you win  ############")
        you_win=you_win + 1
    elif y == "paper" and c == "rock":
        print("       ############   you win  ############")
        you_win = you_win + 1

    elif y == "scissor" and c == "paper":
        print("       ############   you win  ############")
        you_win = you_win + 1
    else:
        print("       ############   computer win  ############")
        computer_win= computer_win + 1
    again = input("want to play game [ y / n ] :")
    if again=="y":
        print("#"*100)

    else:
        print("total draw        :",draw)
        print("you win           :",you_win, " round")
        print("computer win      :",computer_win," round")
        print(empty)
        if computer_win==you_win:
            print("                               final result is draw")
        if  computer_win > you_win:
            print("                               computer win the game")
        if computer_win < you_win:
            print("                      " , name," win the game")
        print(empty)
        print("                                     ### ### ### THANK YOU ### ### ###   ")
        print(empty)
        print("#"*100)
        break
# Out:
#
#                                          WELCOME  IN ROCK//PAPER//SCISSOR  GAME
#                      select your choice  :  ROCK    /    PAPER     /SCISSOR
# enter player name  :pranit
#
# select your choice     :rock
#
# pranit    : rock
# computer   : paper
#        ############   computer win  ############
# want to play game [ y / n ] :y
# ####################################################################################################
# select your choice     :paper
#
# pranit    : paper
# computer   : scissor
#        ############   computer win  ############
# want to play game [ y / n ] :y
# ####################################################################################################
# select your choice     :rock
#
# pranit    : rock
# computer   : paper
#        ############   computer win  ############
# want to play game [ y / n ] :n
# total draw        : 0
# you win           : 0  round
# computer win      : 3  round
#
# ...

# %%
# result

# %%
# part 1


school= '                            \33[1m " J. H . AMBANI PETROCHEMICAL NAGOTHANE SCHOOL"  ' # \33[1m  is for bold
empty="  "
mobile="                                    ph  : 9874657410       gmail ID :ambani@gmail.com"
teacher = "10 th class                            ACADEMIC-YEAR                       class teacher : MR.more sir"
year =("                                           2020-2021")
name=input("                       ENTER STUDENT FULL NAME  :").upper()

f=name.split(" ")
father=f[1]+" "+f[2]

import random
print("#"*108)
print(empty)
print(empty)
print(school)
print(empty)
print(mobile)
print(empty)
print(teacher)
print(year)
print("student name  :",name)
print("father        :",father)
print("roll no       :",random.randint(10,50))
print("attendance    :",random.randint(65,87),"%")
print(empty)
print("#"*108)


# part 2

mo1=int(input("enter 1 oral marks in maths out of 20   : "))
so1=int(input("enter 1 oral marks in sci out of 20     : "))
ho1=int(input("enter 1 oral marks in hist out of 20    : "))
go1=int(input("enter 1 oral marks in geo out of 20     : "))
eo1=int(input("enter 1 oral marks in english out of 20 : "))

mw1=int(input("enter 1 written marks in maths out of 80   : "))
sw1=int(input("enter 1 written marks in sci out of 80     : "))
hw1=int(input("enter 1 written marks in hist out of 80    : "))
gw1=int(input("enter 1 written marks in geo out of 80     : "))
ew1=int(input("enter 1 written marks in english out of 80 : "))


mo2=int(input("enter 2 oral marks in maths out of 20   : "))
so2=int(input("enter 2 oral marks in sci out of 20     : "))
ho2=int(input("enter 2 oral marks in hist out of 20    : "))
go2=int(input("enter 2 oral marks in geo out of 20     : "))
eo2=int(input("enter 2 oral marks in english out of 20 : "))

mw2=int(input("enter 2 written marks in maths out of 80   : "))
sw2=int(input("enter 2 written marks in sci out of 80     : "))
hw2=int(input("enter 2 written marks in hist out of 80    : "))
gw2=int(input("enter 2 written marks in geo out of 80     : "))
ew2=int(input("enter 2 written marks in english out of 80 : "))

r = []

def add(mo1, mw1):
    c = mo1 + mw1
    if c >= 80:
        r.append("A+")
    if c < 80 and c >= 70:
        r.append("A")
    if c < 70 and c >= 60:
        r.append("B")
    if c < 60 and c >= 40:
        r.append("c")
    if c < 40:
        r.append("Fail")

add(mo1, mw1)

r1 = []

def add(so1, sw1):
    c = so1 + sw1
    if c >= 80:
        r1.append("A+")
    if c < 80 and c >= 70:
        r1.append("A")
    if c < 70 and c >= 60:
        r1.append("B")
    if c < 60 and c >= 40:
        r1.append("c")
    if c < 40:
        r1.append("Fail")


add(so1, sw1)

r2 = []

def add(ho1, hw1):
    c = ho1 + hw1
    if c >= 80:
        r2.append("A+")
    if c < 80 and c >= 70:
        r2.append("A")
    if c < 70 and c >= 60:
        r2.append("B")
    if c < 60 and c >= 40:
        r2.append("c")
    if c < 40:
        r2.append("Fail")


add(ho1, hw1)

r3 = []

def add(go1, gw1):
    c = go1 + gw1
    if c >= 80:
        r3.append("A+")
    if c < 80 and c >= 70:
        r3.append("A")
    if c < 70 and c >= 60:
        r3.append("B")
    if c < 60 and c >= 40:
        r3.append("c")
    if c < 40:
        r3.append("Fail")

add(go1, gw1)

r4 = []

def add(eo1, ew1):
    c = eo1 + ew1
    if c >= 80:
        r4.append("A+")
    if c < 80 and c >= 70:
        r4.append("A")
    if c < 70 and c >= 60:
        r4.append("B")
    if c < 60 and c >= 40:
        r4.append("c")
    if c < 40:
        r4.append("Fail")


add(eo1, ew1)

r5 = []

def add(mo2, mw2):
    c = mo2 + mw2
    if c >= 80:
        r5.append("A+")
    if c < 80 and c >= 70:
        r5.append("A")
    if c < 70 and c >= 60:
        r5.append("B")
    if c < 60 and c >= 40:
        r5.append("c")
    if c < 40:
        r5.append("Fail")

add(mo2, mw2)

r6 = []

def add(so2, sw2):
    c = so2 + sw2
    if c >= 80:
        r6.append("A+")
    if c < 80 and c >= 70:
        r6.append("A")
    if c < 70 and c >= 60:
        r6.append("B")
    if c < 60 and c >= 40:
        r6.append("c")
    if c < 40:
        r6.append("Fail")

add(so2, sw2)

r7 = []

def add(ho2, hw2):
    c = ho2 + hw2
    if c >= 80:
        r7.append("A+")
    if c < 80 and c >= 70:
        r7.append("A")
    if c < 70 and c >= 60:
        r7.append("B")
    if c < 60 and c >= 40:
        r7.append("c")
    if c < 40:
        r7.append("Fail")

add(ho2, hw2)

r8 = []

def add(go2, gw2):
    c = go2 + gw2
    if c >= 80:
        r8.append("A+")
    if c < 80 and c >= 70:
        r8.append("A")
    if c < 70 and c >= 60:
        r8.append("B")
    if c < 60 and c >= 40:
        r8.append("c")
    if c < 40:
        r8.append("Fail")

add(go2, gw2)

r9 = []

def add(eo2, ew12):
    c = eo2 + ew2
    if c >= 80:
        r9.append("A+")
    if c < 80 and c >= 70:
        r9.append("A")
    if c < 70 and c >= 60:
        r9.append("B")
    if c < 60 and c >= 40:
        r9.append("c")
    if c < 40:
        r9.append("Fail")

add(eo2, ew2)
t=mo1+so1+ho1+go1+eo1+mw1+sw1+hw1+gw1+ew1+mo2+so2+ho2+go2+eo2+mw2+sw2+hw2+gw2+ew2
import csv

with open("marksheet.csv","w")as fp:
    w=csv.writer(fp)
    w.writerow(["sub","(","1st- half",")","(","2nd- half",")"])
    w.writerow([" ","oral","written","grade","oral","written","grade"])
    w.writerow(["maths",mo1,mw1,r,mo2,mw2,r5])
    w.writerow(["science",so1,sw1,r1,so2,sw2,r6])
    w.writerow(["history",ho1,hw1,r2,ho2,hw2,r7])
    w.writerow(["Geography",go1,gw1,r3,go2,gw2,r8])
    w.writerow(["english",eo1,ew1,r4,eo2,ew2,r9])
    w.writerow([" TOTAL ",mo1+so1+ho1+go1+eo1+mw1+sw1+hw1+gw1+ew1, "/   600  "," ",  mo2+so2+ho2+go2+eo2+mw2+sw2+hw2+gw2+ew2, "/    600 ", " "])
    
import pandas as pd
df=pd.read_csv("marksheet.csv")
print(df)
    
#  part 3

a=" "
print(a)
print("#"*108)
print(a)
print("                                                             out of 1200 you got :",t)
print("                                                             total percentage    :",t/12,"%")
print(a)
if t >=1000:
    print("                                                              PASS with  :     A+ GRADE")
if t<1000 and t >=840:
    print("                                                              PASS with  :     A  GRADE")
if t<840 and t >=720:
   print("                                                               PASS with  :     B  GRADE")
if t<720 and t >=480:
    print("                                                              PASS with  :     c  GRADE")
if t<480:
    print("                                                                             Fail ")

print(a)
print(a)
print(a)
print("  student                                        class teacher                             principal      ")
print("  gardiant                                        MR.more sir                             Dr.rama anand ")
print("(            )                                       द.मोरे                                   रमा.आनंद ")
print(a)
print("#"*108)
# Out:
#                        ENTER STUDENT FULL NAME  :pranit mohan bhoy
# ############################################################################################################
#
#
#                              " J. H . AMBANI PETROCHEMICAL NAGOTHANE SCHOOL"
#
#                                     ph  : 9874657410       gmail ID :ambani@gmail.com
#
# 10 th class                            ACADEMIC-YEAR                       class teacher : MR.more sir
#                                            2020-2021
# student name  : PRANIT MOHAN BHOY
# father        : MOHAN BHOY
# roll no       : 31
# attendance    : 87 %
#
# ############################################################################################################
# enter 1 oral marks in maths out of 20   : 10
# enter 1 oral marks in sci out of 20     : 10
# enter 1 oral marks in hist out of 20    : 10
# enter 1 oral marks in geo out of 20     : 10
# enter 1 oral marks in english out of 20 : 10
# ...
